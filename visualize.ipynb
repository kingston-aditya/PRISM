# %%
import json

# look at the image
pth_lst_txt = "/mnt/ssd/annotations/captions_val2017.json"

# read json file
f = open(pth_lst_txt)
data = json.load(f)
data = data['annotations']

a = {}
l = []
k=0
for sample in data:
    # load image
    img_name = '%012d.jpg' % sample['image_id']
    if img_name not in a.keys():
        a[img_name] = [sample['caption']]

# %%
print("/nfshomes/asarkar6/trinity/trinity-images/4500.png")
# Out:
# /nfshomes/asarkar6/trinity/trinity-images/4500.png

# %%
print("/mnt/ssd/val2017/"+list(a.keys())[1900])
# Out:
# /mnt/ssd/val2017/000000173033.jpg
